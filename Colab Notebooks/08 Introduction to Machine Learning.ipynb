# %% [markdown]
# # __What is Machine learning?__
# #### Machine Learning enables systems to learn from data and make decisions autonomously without explicit programming.
# #### Traditional programming relies on fixed logic, while ML adapts and handles complex, dynamic tasks.
# #### ML models recognize patterns, solve problems, and generalize their learning to unseen data.
# #### Unlike automation, Machine Learning evolves and adjusts based on changing conditions without human intervention.
# #### ML excels in tasks like image recognition, speech processing, and predictive analysis over static automation.
#
#
#
# <table>
#   <tr>
#     <th> Traditional Programming</th>
#     <th>  </th>
#     <th>INPUT</th>
#     <th> + </th>
#     <th> Program/Logic </th>
#     <th> = </th>
#     <th> Result/Output </th>
#
#   <tr>
#     <th </th>
#     <th>  </th>
#     <th> </th>
#     <th> </th>
#     <th> </th>
#     <th> </th>
#     <th>  </th>
#   <tr>
#     <th>Machine Learning  </th>
#     <th>  </th>
#     <th>INPUT</th>
#     <th> + </th>
#     <th> Result/Output </th>
#     <th> = </th>
#     <th> Program/Logic </th>
# </table>

# %% [markdown]
# # __Types of Machine Learning Supervised, Unsupervised and Reinforcement Learning__
# #### There are three types of Machine Learning: __Supervised, Unsupervised, and Reinforcement Learning.__
# #### __Supervised Learning__: Trains on labeled data to predict outcomes, like spam detection or price prediction.
# #### __Unsupervised Learning__: Finds hidden patterns in unlabeled data, used in clustering and anomaly detection.
# #### __Reinforcement Learning__: Learns through trial, error, and rewards, excelling in gaming and robotics applications.
# #### Machine Learning's Power: Adapts dynamically to complex tasks, evolving beyond fixed rules and automation.

# %% [markdown]
# # __Applications of Machine learning__
# #### Machine Learning revolutionizes industries, solving complex problems and driving innovation across technologies.
# #### __Healthcare__: Personalizes treatments, diagnoses diseases, and predicts outcomes using data-driven algorithms.
# #### __Finance__: Detects fraud, analyzes transactions, and automates trading for optimized financial strategies.
# #### __E-commerce__: Enhances shopping experiences with personalized recommendations and efficient inventory management.
# #### __Transportation__: Powers self-driving cars, traffic predictions, and ride-sharing optimizations.
# #### __Entertainment__: Offers content recommendations and adaptive gaming experiences based on user preferences.
# #### __Education__: Creates tailored learning plans, automates grading, and provides intelligent tutoring systems.
# #### __Sustainability__: Improves renewable energy efficiency and supports climate change action via predictive models.
# #### __Advanced Robotics__: Enables robots to learn skills, adapt environments, and interact naturally with humans.
# #### __Autonomous Systems__: Develops autonomous drones, ships, and vehicles for logistics and reduced costs.
# #### __Space Exploration__: Analyzes astronomical data for discoveries and optimizes spacecraft navigation.
# #### __Smart Cities__: Enhances urban living with optimized energy, transportation, and predictive crime prevention systems.
# #### Machine Learning evolves dynamically, shaping industries and tackling future challenges with innovative solutions.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

data_dir = '/content/content/MyDrive/data'

drive.mount('content')
os.chdir(data_dir)
os.listdir()
# Out:
# Mounted at content
# ['train.csv',
#  'feature_details_analysis.xlsx',
#  'data_description.txt',
#  'feature_classification.csv',
#  'train_refined - Copy.csv',
#  'feature_classification - Copy.csv',
#  'train_refined.csv',
#  'train_refined - Copy (2).csv']

# %% [markdown]
# # __Linear Regression Introduction__
# #### __Regression analysis__ predicts the __dependent variable 𝑦 using independent variables 𝑥__ to model relationships.
# #### __Linear regression fits a straight line__, minimizing errors between observed and predicted values: __𝑦 = 𝑚𝑥 + 𝑐__.
# #### __Slope (𝑚)__ quantifies change in 𝑦 for a unit increase in independent variable 𝑥.
# #### __Y-intercept (𝑐)__ identifies 𝑦 value when 𝑥 equals zero; baseline value of the model.
# #### __Scatter plots__ visualize trends, aiding identification of linear relationships for predictive modeling tasks.
# #### Used widely for house price estimation and sales forecasting; simplifies complex relationships into actionable insights.
# #### Ideal for beginners; intuitive and simple methodology to grasp in __machine learning__ workflows.

# %%
df_train_refined = pd.read_csv('train_refined.csv')

# %%
df_train_refined[['GrLivArea', 'SalePrice']].corr()
# Out:
#            GrLivArea  SalePrice
# GrLivArea   1.000000   0.708624
# SalePrice   0.708624   1.000000

# %%
df_train_refined.plot(kind='scatter', x='GrLivArea', y='SalePrice')
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
# y = m * x + c where x is df_train_ref['GrLiveArea']
m = 100
c = 5000
y = m * df_train_refined['GrLivArea'] + c
df_train_refined.plot(kind='scatter', x='GrLivArea', y='SalePrice', marker='x')
plt.plot(df_train_refined['GrLivArea'], y, c='red')
plt.title('Drawing Straigh line through datapoints');

# %% [markdown]
# # __Understanding Scalars, Vectors, Matrices, and Tensors__
# #### **Scalars** represent __single values like 5 or "John__," defined as __1 * 1__ but __0 dimensions.__
# #### **Vectors** are one-dimensional arrays, structured as either __𝑛 * 1 (column) or 1 * 𝑚 (row)__.
# #### __Row Vector__
# <table>
#   <tr>
#     <td>Row 1 Value1</td>
#     <td>Row 1 Value2</td>
#     <td>Row 1 Value3</td>
#   </tr>
# </table>
#
# #### __Column Vector__
# <table>
#   <tr>
#     <td>Col 1 Value1</td>
#   </tr>
#   <tr>
#     <td>Col 1 Value2</td>
#   </tr>
#   <tr>
#     <td>Col 1 Value3</td>
#   </tr>
# </table>
#
# #### **Matrix** is two-dimensional array with multiple rows and columns, defined as __𝑛 * 𝑚 dimensions.__
# <table border="1">
#   <tr>
#     <th>Column 1</th>
#     <th>Column 2</th>
#     <th>Column 3</th>
#     <th>Column 4</th>
#   </tr>
#   <tr>
#     <td>Row 1, Column 1</td>
#     <td>Row 1, Column 2</td>
#     <td>Row 1, Column 3</td>
#     <td>Row 1, Column 4</td>
#   </tr>
#   <tr>
#     <td>Row 2, Column 1</td>
#     <td>Row 2, Column 2</td>
#     <td>Row 2, Column 3</td>
#     <td>Row 2, Column 4</td>
#   </tr>
#   <tr>
#     <td>Row 3, Column 1</td>
#     <td>Row 3, Column 2</td>
#     <td>Row 3, Column 3</td>
#     <td>Row 3, Column 4</td>
#   </tr>
# </table>
#
# #### **Tensors** generalize matrices to three or more dimensions, e.g., __𝑛 * 𝑚 * 𝑝 in notation__.
#
#
# <table style="border-spacing: 20px;">
#   <tr>
#     <!-- Table 1 -->
#     <td>
#       <div><strong>Table 1</strong></div>
#       <table border="1">
#         <tr>
#           <th>Heading 1</th>
#           <th>Heading 2</th>
#         </tr>
#         <tr>
#           <td>Table 1, Row 1, Col 1</td>
#           <td>Table 1, Row 1, Col 2</td>
#         </tr>
#         <tr>
#           <td>Table 1, Row 2, Col 1</td>
#           <td>Table 1, Row 2, Col 2</td>
#         </tr>
#       </table>
#     </td>
#     <!-- Table 2 -->
#     <td>
#       <div><strong>Table 2</strong></div>
#       <table border="1">
#         <tr>
#           <th>Heading 1</th>
#           <th>Heading 2</th>
#         </tr>
#         <tr>
#           <td>Table 2, Row 1, Col 1</td>
#           <td>Table 2, Row 1, Col 2</td>
#         </tr>
#         <tr>
#           <td>Table 2, Row 2, Col 1</td>
#           <td>Table 2, Row 2, Col 2</td>
#         </tr>
#       </table>
#     </td>
#   </tr>
#   <tr>
#     <!-- Table 3 -->
#     <td>
#       <div><strong>Table 3</strong></div>
#       <table border="1">
#         <tr>
#           <th>Heading 1</th>
#           <th>Heading 2</th>
#         </tr>
#         <tr>
#           <td>Table 3, Row 1, Col 1</td>
#           <td>Table 3, Row 1, Col 2</td>
#         </tr>
#         <tr>
#           <td>Table 3, Row 2, Col 1</td>
#           <td>Table 3, Row 2, Col 2</td>
#         </tr>
#       </table>
#     </td>
#     <!-- Table 4 -->
#     <td>
#       <div><strong>Table 4</strong></div>
#       <table border="1">
#         <tr>
#           <th>Heading 1</th>
#           <th>Heading 2</th>
#         </tr>
#         <tr>
#           <td>Table 4, Row 1, Col 1</td>
#           <td>Table 4, Row 1, Col 2</td>
#         </tr>
#         <tr>
#           <td>Table 4, Row 2, Col 1</td>
#           <td>Table 4, Row 2, Col 2</td>
#         </tr>
#       </table>
#     </td>
#   </tr>
# </table>
#
# ####  Scalars, vectors, matrices, and tensors organize data, bridging raw input to meaningful insights effectively.
# #### __Numpy and Pandas__ simplify the usage of these structures, supporting machine learning workflows seamlessly.

# %%
print(df_train_refined.iloc[10,10])
# Out:
# 3.0

# %%
print(df_train_refined.iloc[5,15])
# Out:
# Y

# %%
df_train_refined['LotArea']
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
df_train_refined.loc[:,'GarageYrBlt']
# Out:
# 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 1455    1999.0
# 1456    1978.0
# 1457    1941.0
# 1458    1950.0
# 1459    1965.0
# Name: GarageYrBlt, Length: 1460, dtype: float64

# %%
df_train_refined.loc[0]
# Out:
# Id                    1
# LotFrontage        65.0
# LotArea            8450
# Neighborhood    CollgCr
# OverallQual           7
# YearBuilt          2003
# YearRemodAdd       2003
# MasVnrArea        196.0
# ExterQual             4
# Foundation        PConc
# BsmtQual            4.0
# BsmtFinSF1          706
# BsmtUnfSF           150
# TotalBsmtSF         856
# HeatingQC             5
# CentralAir            Y
# Electrical        SBrkr
# 1stFlrSF            856
# 2ndFlrSF            854
# GrLivArea          1710
# FullBath              2
# HalfBath              1
# BedroomAbvGr          3
# KitchenAbvGr          1
# KitchenQual           4
# Fireplaces            0
# GarageType       Attchd
# GarageYrBlt      2003.0
# GarageFinish        RFn
# GarageCars            2
# GarageArea          548
# WoodDeckSF            0
# OpenPorchSF          61
# SalePrice        208500
# Name: 0, dtype: object

# %%
df_train_refined.tail()
# Out:
#         Id  LotFrontage  LotArea Neighborhood  OverallQual  YearBuilt  \
# 1455  1456         62.0     7917      Gilbert            6       1999
# 1456  1457         85.0    13175       NWAmes            6       1978
# 1457  1458         66.0     9042      Crawfor            7       1941
# 1458  1459         68.0     9717        NAmes            5       1950
# 1459  1460         75.0     9937      Edwards            5       1965
#
#       YearRemodAdd  MasVnrArea  ExterQual Foundation  ...  KitchenQual  \
# 1455          2000         0.0          3      PConc  ...            3
# 1456          1988       119.0          3     CBlock  ...            3
# 1457          2006         0.0          5      Stone  ...            4
# 1458          1996         0.0          3     CBlock  ...            4
# 1459          1965         0.0          4     CBlock  ...            3
#
#       Fireplaces  GarageType  GarageYrBlt  GarageFinish GarageCars GarageArea  \
# ...

# %% [markdown]
# # __Linear regression in Machine Learning__
# #### __Vectorization in Pandas__ simplifies complex data relationships, making calculations straightforward and efficient.
# #### Each column in the dataset contains 1460 rows, ensuring proper correspondence between x and y values.
# #### Our goal is to predict house sale prices based on living area, using a machine learning model.
# #### __Straight-line equation__ demonstrates the power of machine learning to estimate y values effectively.

# %%
df_train_refined[['GrLivArea', 'SalePrice']].head(20)
# Out:
#     GrLivArea  SalePrice
# 0        1710     208500
# 1        1262     181500
# 2        1786     223500
# 3        1717     140000
# 4        2198     250000
# 5        1362     143000
# 6        1694     307000
# 7        2090     200000
# 8        1774     129900
# 9        1077     118000
# 10       1040     129500
# 11       2324     345000
# 12        912     144000
# 13       1494     279500
# 14       1253     157000
# 15        854     132000
# 16       1004     149000
# 17       1296      90000
# 18       1114     159000
# 19       1339     139000

# %%
df_train_refined[['GrLivArea', 'SalePrice']].shape
# Out:
# (1460, 2)

# %%
# y = m * x + c where x is df_train_ref['GrLiveArea']
m = 100
c = 5000
x_intersect = 2500
y_intersect = m * x_intersect + c

y = m * df_train_refined['GrLivArea'] + c
df_train_refined.plot(kind='scatter', x='GrLivArea', y='SalePrice', marker='x')
plt.plot(df_train_refined['GrLivArea'], y, c='red')

# Vertical line ending at the straight line
plt.plot([x_intersect, x_intersect], [0, y_intersect], color='blue', linestyle='--', linewidth=3, label=f'Vertical Line to y={y_intersect}')

# Horizontal line ending at the straight line
plt.plot([0, x_intersect], [y_intersect, y_intersect], color='green', linestyle='--', linewidth=3, label=f'Horizontal Line to x={x_intersect}')

plt.xlim(0,None)
plt.ylim(0, None)

plt.title('Finding Sale Price for 2500 sq ft Living Area');

# %%
model_dataframe = df_train_refined[['GrLivArea', 'SalePrice']]
model_dataframe.head()
# Out:
#    GrLivArea  SalePrice
# 0       1710     208500
# 1       1262     181500
# 2       1786     223500
# 3       1717     140000
# 4       2198     250000

# %%
model_dataframe = df_train_refined[['GrLivArea', 'SalePrice']].rename(columns = {
    'GrLivArea': 'x',
    'SalePrice': 'y'})
model_dataframe.head()
# Out:
#       x       y
# 0  1710  208500
# 1  1262  181500
# 2  1786  223500
# 3  1717  140000
# 4  2198  250000

# %%
model_dataframe['y_pred'] = model_dataframe['x'] * m
model_dataframe.head()
# Out:
#       x       y  y_pred
# 0  1710  208500  171000
# 1  1262  181500  126200
# 2  1786  223500  178600
# 3  1717  140000  171700
# 4  2198  250000  219800

# %%
# y = m * x + c where x is df_train_ref['GrLiveArea']
m = 100
c = 5000

staright_line = m * model_dataframe['x'] + c

ax = model_dataframe.plot(kind='scatter', x='x', y='y', marker='x', label='Actual y value')
model_dataframe.plot(kind='scatter', x='x', y='y_pred', marker = 'o', c='g', label='Predicted y value', ax=ax)
plt.plot(model_dataframe['x'], staright_line, c='red')

# %% [markdown]
# # __Introduction to cost function Mean Squared Error (MSE)__
# * Straight line equation used in __Machine learning__ is $\boldsymbol{y = wx + b}$ instead of $\boldsymbol{y = mx + c}$
# * Erros in prediction is calcuatled by $\boldsymbol{(y_{\text{pred}} - y)}$
# * To avoid negative value it is squared $\boldsymbol{(y_{\text{pred}} - y)^2}$
# * Error calculation General form $\boldsymbol{(y_{\text{pred}}^{(i)} - y^{(i)})^2}$
# * Error calculation for first point $\boldsymbol{(y_{\text{pred}}^{(0)} - y^{(0)})^2}$
# * Error calculation for second point $\boldsymbol{(y_{\text{pred}}^{(1)} - y^{(1)})^2}$
# * Error calculation for 10th point $\boldsymbol{(y_{\text{pred}}^{(9)} - y^{(9)})^2}$
# * Error calculation for last point $\boldsymbol{(y_{\text{pred}}^{(1459)} - y^{(1459)})^2}$
# * Summing all the errors $\boldsymbol{(y_{\text{pred}}^{(0)} - y^{(0)})^2} + {(y_{\text{pred}}^{(1)} - y^{(1)})^2} + {(y_{\text{pred}}^{(2)} - y^{(2)})^2 ....... {(y_{\text{pred}}^{(1459)} - y^{(1459)})^2}} $
# * Taking the mean of the sum $\boldsymbol{\frac{1}{1460} \left[ (y_{\text{pred}}^{(0)} - y^{(0)})^2 + (y_{\text{pred}}^{(1)} - y^{(1)})^2 + (y_{\text{pred}}^{(2)} - y^{(2)})^2 + \dots + (y_{\text{pred}}^{(1459)} - y^{(1459)})^2 \right]}$
# * Sum of errors of all the points $\boldsymbol{\frac{1}{1460} \Sigma_{i=0}^{1459} (y_{\text{pred}}^{(i)} - y^{(i)})^2}$
# * Mean Sqaure Error  $\boldsymbol {MSE =} {\frac{1}{m} \Sigma_{i}^{m} (y_{\text{pred}}^{(i)} - y^{(i)})^2}$

# %%
model_dataframe['squared error'] = (model_dataframe['y_pred'] - model_dataframe['y']).pow(2)
model_dataframe.head()
# Out:
#       x       y  y_pred  squared error
# 0  1710  208500  171000     1406250000
# 1  1262  181500  126200     3058090000
# 2  1786  223500  178600     2016010000
# 3  1717  140000  171700     1004890000
# 4  2198  250000  219800      912040000

# %%
error = model_dataframe['squared error'].sum()/model_dataframe.shape[0]
print(f'{error:.2f}')
# Out:
# 4016752986.12

# %%
# Plot the actual and predicted values
ax = model_dataframe.iloc[:10].plot(kind='scatter', x='x', y='y', marker='x', label='Actual y value')
model_dataframe.iloc[:10].plot(kind='scatter', x='x', y='y_pred', marker='o', c='g', label='Predicted y value', ax=ax)

# Draw lines between actual and predicted values
for i in range(len(model_dataframe.iloc[:10])):
    plt.plot(
        [model_dataframe['x'].iloc[i], model_dataframe['x'].iloc[i]],  # x remains constant
        [model_dataframe['y'].iloc[i], model_dataframe['y_pred'].iloc[i]],  # y changes between actual and predicted
        c='gray', linestyle='--', label='Difference' if i == 0 else ""  # Label only once
    )

plt.legend()
plt.show()

# %%
# Plot the actual and predicted values for data points 100 to 149
ax = model_dataframe.iloc[100:150].plot(kind='scatter', x='x', y='y', marker='x', label='Actual y value')
model_dataframe.iloc[100:150].plot(kind='scatter', x='x', y='y_pred', marker='o', c='g', label='Predicted y value', ax=ax)

# Draw lines between actual and predicted values for the specified range
for i in range(len(model_dataframe.iloc[100:150])):
    plt.plot(
        [model_dataframe['x'].iloc[100 + i], model_dataframe['x'].iloc[100 + i]],  # x remains constant for each point
        [model_dataframe['y'].iloc[100 + i], model_dataframe['y_pred'].iloc[100 + i]],  # y changes between actual and predicted
        c='gray', linestyle='--', label='Difference' if i == 0 else ""  # Label the first line only
    )

plt.legend()
plt.show()

# %% [markdown]
# # __Key Parameters or coefficient Slope w and y-intercept b__
# * We can write our straight line equation as $\boldsymbol{f_{w,b}(x) = w \cdot x + b}$ instead of $\boldsymbol{y = w \cdot x + b}$
# * or simply it can be written $\boldsymbol{f(x) = w \cdot x + b}$
# * $\boldsymbol{w,b}$ are called __parameters or coefficients or weights__ in machine learning
# * Similary MSE can be expressed as $\boldsymbol{J(w, b) =\frac{1}{m} \Sigma_{i}^{m} (y_{\text{pred}}^{(i)} - y^{(i)})^2}$
# * As $\boldsymbol{y_{\text{pred}} = f_{w,b}(x^{(i)})}$ therefore cost function will change to $\boldsymbol{J(w, b) =\frac{1}{m} \Sigma_{i}^{m} (f_{w,b}(x^{(i)}) - y^{(i)})^2}$
# * __Our goal is to find best value of slope w which will minimize our MSE__
# * For simplification we have set y-intecept b = 0

# %%
# Define x values
x = range(5)  # x values from 0 to 4

# Define the conditions
conditions = [
    {"w": 0, "b": 2, "label": "w=0, b=2"},
    {"w": 1, "b": 0, "label": "w=1, b=0"},
    {"w": 1, "b": 1, "label": "w=1, b=1"}
]

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Generate each subplot
for i, condition in enumerate(conditions):
    w = condition["w"]
    b = condition["b"]
    label = condition["label"]
    y = [w * val + b for val in x]  # Straight-line equation

    axs[i].plot(x, y, label=label)  # Plot the line
    axs[i].set_title(label)  # Use the label as the title
    axs[i].set_xlim(0, 5)  # Set x-axis limit from 0 to infinity
    axs[i].set_ylim(0, 5)  # Set y-axis limit from 0 to infinity
    axs[i].grid(True)  # Enable grid
    axs[i].legend(loc="best", fontsize=10)  # Add the label as legend

# Set overall layout
plt.tight_layout()
plt.show()

# %%
mean_squared_errors = {}  # Initialize a dictionary to store mean squared errors

# Single loop to handle all operations
for w in range(-2000, 2001, 50):  # w values from -2000 to 2000, step 50
    # Generate predicted values
    col_name_pred = f'y_pred_w{w}'  # Predicted value column
    model_dataframe[col_name_pred] = model_dataframe['x'] * w  # Calculate y_pred = w * x

    # Calculate squared errors
    col_name_error = f'squared_error_w{w}'  # Squared error column
    model_dataframe[col_name_error] = (model_dataframe[col_name_pred] - model_dataframe['y']) ** 2  # Squared error calculation

    # Calculate mean squared error
    mean_squared_errors[w] = model_dataframe[col_name_error].mean()  # Compute mean squared error

# Create a new DataFrame for mean squared errors
mean_squared_error_df = pd.DataFrame(
    list(mean_squared_errors.items()),
    columns=['Slope (w)', 'Mean Squared Error']
)

mean_squared_error_df.head(50)
# Out:
# <ipython-input-24-724ea05e1cf3>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   model_dataframe[col_name_error] = (model_dataframe[col_name_pred] - model_dataframe['y']) ** 2  # Squared error calculation
# <ipython-input-24-724ea05e1cf3>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   model_dataframe[col_name_pred] = model_dataframe['x'] * w  # Calculate y_pred = w * x
# ...

# %%
# Sort slopes and plot
mean_squared_error_df.sort_values(by='Slope (w)', inplace=True)  # Sort by slope
mean_squared_error_df.plot(x='Slope (w)', y='Mean Squared Error', kind='line')
plt.title('Mean Squared Error vs. Slope (w)')
plt.xlabel('w')
plt.ylabel(r'$\boldsymbol{J(w)}$')
plt.grid(True)
plt.show()

# %%
# Constants
b = 0  # Intercept
w_values = range(-250, 251, 50)  # Slope values from -250 to 250 with step size 50

# Set up subplots for two side-by-side graphs
fig, axes = plt.subplots(1, 2, figsize=(15, 6))  # 1 row, 2 columns

# First plot: Impact of different slopes (w) on Sale Price Prediction
ax = model_dataframe.plot(kind='scatter', x='x', y='y', marker='x', label='Actual y value', ax=axes[0])
model_dataframe.plot(kind='scatter', x='x', y='y_pred', marker='o', c='g', label='Predicted y value', ax=ax)

for w in w_values:
    straight_line = w * model_dataframe['x'] + b  # Calculate straight line
    if w == 100 or w == 150:
        axes[0].plot(model_dataframe['x'], straight_line, label=f'w={w}', linewidth=2.5, color='red')  # Highlight specific lines
    else:
        axes[0].plot(model_dataframe['x'], straight_line, label=f'w={w}', linewidth=1)  # Regular lines

axes[0].set_xlabel('GrLiveArea (Living Area)')
axes[0].set_ylabel('SalePrice')
axes[0].set_title('Impact of Different Slopes (w) on Sale Price Prediction')
axes[0].legend(loc='best', fontsize='small')
axes[0].grid(True)

# Second plot: Mean Squared Error vs. Slope (w)
mean_squared_error_df.sort_values(by='Slope (w)', inplace=True)  # Sort by slope
axes[1].plot(mean_squared_error_df['Slope (w)'], mean_squared_error_df['Mean Squared Error'], marker='o')
axes[1].set_title('Mean Squared Error vs. Slope (w)')
axes[1].set_xlabel('w')
axes[1].set_ylabel(r'$\boldsymbol{J(w)}$')
axes[1].grid(True)

# Adjust layout and display plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # __Introduction to Gradient descent algorithm__
# * Python uses the __(=)__ sign for __assignment__, storing the value on the left-hand side.
# * The __(==)__ sign in Python is for __comparisons__; it checks if two values are equal.
# * __Gradient descent__ minimizes the __cost function__ by __iteratively__ adjusting w and b parameters.
# * __Derivatives__ measure rate of change in cost function to refine w and b values.
# * Python libraries automate calculus processes, simplifying complex mathematical operations for machine learning tasks.

# %%
a = 5
a
# Out:
# 5

# %%
a = a + 2
a
# Out:
# 7

# %%
a = 9
b = 9
c = 7

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
c == b
# Out:
# False

# %% [markdown]
# * The derivative for $\boldsymbol{w}$ is $\boldsymbol{\frac{\partial J(w, b)}{\partial w}}$
# * The derivative for $\boldsymbol{b}$ is $\boldsymbol{\frac{\partial J(w, b)}{\partial b}}$
# * $\boldsymbol{w = w - \frac{\partial J(w, b)}{\partial w}}$
# * $\boldsymbol{b = b - \frac{\partial J(w, b)}{\partial b} }$
# * $\boldsymbol{w_{\text{temp}} = w - \frac{\partial J(w, b)}{\partial w}}$
# * $\boldsymbol{b_{\text{temp}} = b - \frac{\partial J(w, b)}{\partial b} }$
# * $\boldsymbol{w = w_{\text{temp}}}$
# * $\boldsymbol{b = b_{\text{temp}}}$

# %% [markdown]
# # __What is Gradient Descent__
# * The __gradient__ is the __numerical value__ of the slope of a tangent line on a curve.
# * It measures how __steep__ the curve is at a specific point.
# * __Gradients descent__ guide optimization by showing the direction and rate of change in functions.
# * __Negative gradients__ occur on the left side of a curve, while __positive gradients__ occur on the right.
# * __Gradient descent__ uses gradients to __iteratively__ minimize the __cost function__ step by step.
# * At the __minimum value__ of the curve, the gradient becomes __zero__, indicating no slope.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the curve
w = np.linspace(-10, 10, 100)
j_w = w**2  # Example of a quadratic curve

# Define tangent points and slopes
w_neg = -5  # Left side of the curve for negative slope
w_pos = 5   # Left side of the curve for positive slope
negative_slope = 2 * w_neg  # Slope at w = -5
positive_slope = 2 * w_pos  # Slope at w = 5

# Generate shorter tangent lines
tangent_length = 2
w_tangent_neg = np.linspace(w_neg - tangent_length, w_neg + tangent_length, 10)
w_tangent_pos = np.linspace(w_pos - tangent_length, w_pos + tangent_length, 10)

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# First subplot: negative slope
axs[0].plot(w, j_w, label='Curve of J(w)')
axs[0].plot(w_neg, w_neg**2, 'ro', label='Point of Tangency')
axs[0].plot(w_tangent_neg, negative_slope * (w_tangent_neg - w_neg) + w_neg**2,
            label='Tangent Line (-ve Slope)', linestyle='--')
axs[0].set_title('Negative Slope')
axs[0].set_xlabel('w')
axs[0].set_ylabel('J(w)')
axs[0].legend()
axs[0].text(w_neg - 1, w_neg**2 + 10, '-ve slope', fontsize=12, color='blue')

# Second subplot: positive slope
axs[1].plot(w, j_w, label='Curve of J(w)')
axs[1].plot(w_pos, w_pos**2, 'ro', label='Point of Tangency')
axs[1].plot(w_tangent_pos, positive_slope * (w_tangent_pos - w_pos) + w_pos**2,
            label='Tangent Line (+ve Slope)', linestyle='--')
axs[1].set_title('Positive Slope')
axs[1].set_xlabel('w')
axs[1].set_ylabel('J(w)')
axs[1].legend()
axs[1].text(w_pos - 1, w_pos**2 + 10, '+ve slope', fontsize=12, color='green')

# Display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the curve
w = np.linspace(-10, 10, 100)
j_w = w**2  # Example quadratic curve: J(w) = w^2

# Define tangent points
tangent_points = [-9, -5, -2, 0, 2, 5, 9]  # Includes left, right, and flat point
slopes = [2 * w for w in tangent_points]  # Compute slopes (derivatives)

# Generate shorter tangent lines
tangent_length = 2  # Tangent line length
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the curve
ax.plot(w, j_w, label='Curve of J(w)', color='blue')

# Add tangent lines
for point, slope in zip(tangent_points, slopes):
    w_tangent = np.linspace(point - tangent_length, point + tangent_length, 10)
    tangent_line = slope * (w_tangent - point) + point**2

    # Avoid crossing the flat line for bottom tangent lines
    if point == 0:
        ax.plot(w_tangent, tangent_line, color='red', linestyle='--', label='Flat Tangent')
    else:
        ax.plot(w_tangent, tangent_line, color='red', linestyle='--')

# Highlight the flat tangent
ax.plot(0, 0**2, 'ro', label='Flat Tangent (Gradient=0)')

# Add labels and title
ax.set_title("Tangents on J(w) Curve Demonstrating Gradients")
ax.set_xlabel("w")
ax.set_ylabel("J(w)")

# Display the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the curve
w = np.linspace(-10, 10, 100)
j_w = w**2  # Quadratic curve: J(w) = w^2

# Define gradient descent points following the specified pattern
gradient_points = [-9, -6, -3, -1, 3, 5, -2, 1, 0]  # Progression toward minimum with corrections

# Create a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(12, 12))
fig.suptitle("Demonstration of Gradient Descent", fontsize=16)

# Iterate through subplots and plot each step
for i, ax in enumerate(axs.flat):
    if i < len(gradient_points):
        # Plot the curve
        ax.plot(w, j_w, color='blue', label='Curve of J(w)')

        # Plot previous points in blue
        for j in range(i):
            prev_point = gradient_points[j]
            ax.plot(prev_point, prev_point**2, 'bo', label='Previous Point')

        # Plot current point in red
        current_point = gradient_points[i]
        ax.plot(current_point, current_point**2, 'ro', label='Current Point')

        # Add an arrow indicating direction if not the last point
        if i < len(gradient_points) - 1:
            next_point = gradient_points[i + 1]
            ax.arrow(current_point, current_point**2, next_point - current_point,
                     next_point**2 - current_point**2, head_width=0.5, head_length=1, fc='green', ec='green')

        # Title and labels for each subplot
        ax.set_title(f"Step {i + 1}")
        ax.set_xlabel("w")
        ax.set_ylabel("J(w)")

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# # __Learning rate__
# - To overcome gradient descent oscillations around the minimum, the learning rate is introduced.
# - The learning rate helps scale down derivative impact, allowing controlled and stable parameter updates.
# - Proper application of a learning rate ensures convergence to the minimum without overshooting.
# - A small learning rate slows down progress, while a large one can cause instability.
# - Fine-tuning the learning rate accelerates convergence and ensures efficient gradient descent optimization.

# %% [markdown]
# * Learnign rate application to Gradient Descent algorithm
#   * $w = w - \alpha \cdot \frac{\partial J(w, b)}{\partial w}$
#   * $b = b - \alpha \cdot \frac{\partial j(w, b)}{\partial b}$

# %%
# Generate data for the curve
w = np.linspace(-10, 10, 100)
j_w = w**2  # Quadratic curve: J(w) = w^2

# Define gradient descent points with very small updates (simulating a very small learning rate)
gradient_points = [-9, -8.5, -8.0, -7.5, -7.0, -6.5, -6.0, -5.5, -5.0]  # Slow progression toward minimum

# Create a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(12, 12))
fig.suptitle("Impact of Very Small Learning Rate on Gradient Descent", fontsize=16)

# Iterate through subplots and plot each step
for i, ax in enumerate(axs.flat):
    if i < len(gradient_points):
        # Plot the curve
        ax.plot(w, j_w, color='blue', label='Curve of J(w)')

        # Plot previous points in blue
        for j in range(i):
            prev_point = gradient_points[j]
            ax.plot(prev_point, prev_point**2, 'bo', label='Previous Point')

        # Plot current point in red
        current_point = gradient_points[i]
        ax.plot(current_point, current_point**2, 'ro', label='Current Point')

        # Add an arrow indicating direction if not the last point
        if i < len(gradient_points) - 1:
            next_point = gradient_points[i + 1]
            ax.arrow(current_point, current_point**2, next_point - current_point,
                     next_point**2 - current_point**2, head_width=0.5, head_length=1, fc='green', ec='green')

        # Title and labels for each subplot
        ax.set_title(f"Step {i + 1}")
        ax.set_xlabel("w")
        ax.set_ylabel("J(w)")

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Generate data for the curve
w = np.linspace(-10, 10, 100)
j_w = w**2  # Quadratic curve: J(w) = w^2

# Define gradient descent points with large updates while remaining within the curve range
gradient_points = [-9, -4, 3, -6, 5, -3, 6, -1, 2]  # Large jumps but staying within the curve's bounds

# Create a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(12, 12))
fig.suptitle("Impact of Large Learning Rate on Gradient Descent (Within Bounds)", fontsize=16)

# Iterate through subplots and plot each step
for i, ax in enumerate(axs.flat):
    if i < len(gradient_points):
        # Plot the curve
        ax.plot(w, j_w, color='blue', label='Curve of J(w)')

        # Plot previous points in blue
        for j in range(i):
            prev_point = gradient_points[j]
            ax.plot(prev_point, prev_point**2, 'bo', label='Previous Point')

        # Plot current point in red
        current_point = gradient_points[i]
        ax.plot(current_point, current_point**2, 'ro', label='Current Point')

        # Add arrows showing large jumps, maintaining jumps within the curve
        if i < len(gradient_points) - 1:
            next_point = gradient_points[i + 1]
            ax.arrow(
                current_point, current_point**2,
                next_point - current_point, next_point**2 - current_point**2,
                head_width=0.5, head_length=1, fc='red', ec='red'
            )

        # Title and labels for each subplot
        ax.set_title(f"Step {i + 1}")
        ax.set_xlabel("w")
        ax.set_ylabel("J(w)")

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Generate data for the quadratic curve
w = np.linspace(-10, 10, 100)  # Range of w
j_w = w**2  # Quadratic function J(w) = w^2

# Define gradient descent points for both cases
# Case 1: Without learning rate (wild, uncontrolled updates)
gradient_points_no_lr = [-9, 8, -7, 7, -6, 6, -5, 5, -4]

# Case 2: With learning rate (scaled, gradual updates)
learning_rate = 0.3
gradient_points_lr = []
current_w = -9  # Starting point
for _ in range(9):  # Generate points with learning rate applied
    gradient_points_lr.append(current_w)
    current_w = current_w - learning_rate * (2 * current_w)  # Update using gradient descent formula

# Create subplots for side-by-side comparison
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle("Comparison of Gradient Descent Without and With Learning Rate", fontsize=16)

# Plot 1: Without Learning Rate
ax[0].plot(w, j_w, color="blue", label="Curve of J(w)")
colors_no_lr = plt.cm.viridis(np.linspace(0, 1, len(gradient_points_no_lr)))  # Different colors for steps
for i in range(len(gradient_points_no_lr) - 1):
    # Plot points
    ax[0].scatter(
        gradient_points_no_lr[i],
        gradient_points_no_lr[i]**2,
        color=colors_no_lr[i],
        label=f"Step {i + 1}" if i == 0 else None,
    )
    # Draw arrows showing updates
    ax[0].arrow(
        gradient_points_no_lr[i],
        gradient_points_no_lr[i]**2,
        gradient_points_no_lr[i + 1] - gradient_points_no_lr[i],
        gradient_points_no_lr[i + 1]**2 - gradient_points_no_lr[i]**2,
        head_width=0.5,
        head_length=1,
        fc=colors_no_lr[i],
        ec=colors_no_lr[i],
    )
ax[0].set_title("Without Learning Rate")
ax[0].set_xlabel("w")
ax[0].set_ylabel("J(w)")
ax[0].legend()

# Plot 2: With Learning Rate
ax[1].plot(w, j_w, color="blue", label="Curve of J(w)")
colors_lr = plt.cm.plasma(np.linspace(0, 1, len(gradient_points_lr)))  # Different colors for steps
for i in range(len(gradient_points_lr) - 1):
    # Plot points
    ax[1].scatter(
        gradient_points_lr[i],
        gradient_points_lr[i]**2,
        color=colors_lr[i],
        label=f"Step {i + 1}" if i == 0 else None,
    )
    # Draw arrows showing updates
    ax[1].arrow(
        gradient_points_lr[i],
        gradient_points_lr[i]**2,
        gradient_points_lr[i + 1] - gradient_points_lr[i],
        gradient_points_lr[i + 1]**2 - gradient_points_lr[i]**2,
        head_width=0.5,
        head_length=1,
        fc=colors_lr[i],
        ec=colors_lr[i],
    )
ax[1].set_title("With Learning Rate (α = 0.3)")
ax[1].set_xlabel("w")
ax[1].set_ylabel("J(w)")
ax[1].legend()

# Adjust layout and show the plots
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# # __Feature Scaling__
# - **Scaling** adjusts data to comparable ranges, ensuring fair contribution of features to the model.
# - __Data scaling__ ensures numerical features are adjusted to comparable ranges, improving model accuracy.
# - Proper scaling optimizes the slope and intercept, enhancing the alignment of regression models.
# - Python simplifies preprocessing by calculating statistics like mean and standard deviation effortlessly.
# - Applying the algorithm to our dataset helps evaluate its performance and test our understanding.

# %%
del(model_dataframe)
model_dataframe = df_train_refined[['GrLivArea', 'SalePrice']].rename(columns = {
    'GrLivArea': 'x',
    'SalePrice': 'y'})

model_dataframe.head()
# Out:
#       x       y
# 0  1710  208500
# 1  1262  181500
# 2  1786  223500
# 3  1717  140000
# 4  2198  250000

# %%
# Gradient Descent Parameters
learning_rate = 0.1  # Reduced learning rate for stability
iterations = 5000  # Increased iterations for smoother convergence
w = -2000  # Start with a small slope value
b = 0  # Intercept remains constant
gradient_descent_history = []  # To store w values and corresponding MSE during gradient descent

# Perform Gradient Descent
for _ in range(iterations):
    # Generate predicted values based on current slope (w)
    model_dataframe['y_pred'] = w * model_dataframe['x'] + b

    # Calculate Gradient (dMSE/dw)
    gradient = 2 * ((model_dataframe['x'] * ((w * model_dataframe['x']) - model_dataframe['y'])).mean())

    # Update w using gradient descent formula
    w = w - learning_rate * gradient

    # Calculate Mean Squared Error
    mse = ((model_dataframe['y_pred'] - model_dataframe['y']) ** 2).mean()
    gradient_descent_history.append((w, mse))  # Store slope and corresponding MSE

    # Log for debugging
    # print(f"Iteration {_ + 1}: Gradient = {gradient:.4f}, w = {w:.4f}, MSE = {mse:.4f}")

# Convert Gradient Descent History to DataFrame
gradient_descent_df = pd.DataFrame(
    gradient_descent_history,
    columns=['Slope (w)', 'Mean Squared Error']
)

# Sort the gradient_descent_df by Slope (w) for proper plotting
gradient_descent_df = gradient_descent_df.sort_values(by='Slope (w)')

# Find the most optimal slope (w) and corresponding mean squared error
optimal_w = gradient_descent_df.loc[gradient_descent_df['Mean Squared Error'].idxmin(), 'Slope (w)']
min_mse = gradient_descent_df['Mean Squared Error'].min()
print(optimal_w)
# Visualization
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# First Plot: Scatter Plot with Best Fit Line
axes[0].scatter(model_dataframe['x'], model_dataframe['y'], color='blue', label='Actual Data')
model_dataframe['optimal_y_pred'] = optimal_w * model_dataframe['x']  # Generate predictions using optimal_w
axes[0].plot(model_dataframe['x'], model_dataframe['optimal_y_pred'], color='red', label=f'Best Fit Line (w={optimal_w:.4f})', linewidth=2)
axes[0].set_xlabel('GrLivArea (Living Area)')
axes[0].set_ylabel('SalePrice')
axes[0].set_title('Scatter Plot with Best Fit Line (Using Gradient Descent)')
axes[0].legend()
axes[0].grid(True)

# Second Plot: MSE vs Slope (w)
axes[1].plot(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], marker='o', color='green', label='MSE vs Slope (w)')
axes[1].scatter(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], color='red')
axes[1].axhline(y=min_mse, color='blue', linestyle='--', label=f'Minimum MSE = {min_mse:.4f}')
axes[1].set_title(r'$J(w, b)$ vs Slope (w)')
axes[1].set_xlabel(r'Slope $(w)$')
axes[1].set_ylabel(r'$J(w, b)$')  # Using Latex for the y-axis title
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# <ipython-input-40-cd4f5ca78ef6>:17: RuntimeWarning: invalid value encountered in scalar subtract
#   w = w - learning_rate * gradient
# 1089774512.1120548

# %% [markdown]
# - Equation to scale a value
# - $\boxed{\color{blue}{\boldsymbol{x_{\text{scaled}} = \frac{x - \text{mean}(X)}{\text{std}(X)}}}}$

# %%
# Calculate scaled values
model_dataframe['x_scaled'] = (model_dataframe['x'] - model_dataframe['x'].mean()) / model_dataframe['x'].std()
model_dataframe['y_scaled'] = (model_dataframe['y'] - model_dataframe['y'].mean()) / model_dataframe['y'].std()

# %%
# Gradient Descent Parameters
learning_rate = 0.9  # Reduced learning rate for stability
iterations = 50  # Increased iterations for smoother convergence
w = -50  # Start with a small slope value
b = 0  # Intercept remains constant
gradient_descent_history = []  # To store w values and corresponding MSE during gradient descent

# Perform Gradient Descent
for _ in range(iterations):
    # Generate predicted values based on current slope (w)
    model_dataframe['y_pred_scale'] = w * model_dataframe['x_scaled'] + b

    # Calculate Gradient (dMSE/dw)
    gradient = 2 * ((model_dataframe['x_scaled'] * ((w * model_dataframe['x_scaled']) - model_dataframe['y_scaled'])).mean())

    # Update w using gradient descent formula
    w = w - learning_rate * gradient

    # Calculate Mean Squared Error
    mse = ((model_dataframe['y_pred_scale'] - model_dataframe['y_scaled']) ** 2).mean()
    gradient_descent_history.append((w, mse))  # Store slope and corresponding MSE

    # Log for debugging
    # print(f"Iteration {_ + 1}: Gradient = {gradient:.4f}, w = {w:.4f}, MSE = {mse:.4f}")

# Convert Gradient Descent History to DataFrame
gradient_descent_df = pd.DataFrame(
    gradient_descent_history,
    columns=['Slope (w)', 'Mean Squared Error']
)

# Sort the gradient_descent_df by Slope (w) for proper plotting
gradient_descent_df = gradient_descent_df.sort_values(by='Slope (w)')

# Find the most optimal slope (w) and corresponding mean squared error
optimal_w = gradient_descent_df.loc[gradient_descent_df['Mean Squared Error'].idxmin(), 'Slope (w)']
min_mse = gradient_descent_df['Mean Squared Error'].min()
print('-'*80)
print(f'Scaled Slope value is: {optimal_w:.2f}')
print('-'*80)
# Visualization
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# First Plot: Scatter Plot with Best Fit Line
axes[0].scatter(model_dataframe['x_scaled'], model_dataframe['y_scaled'], color='blue', label='Actual Data')
model_dataframe['optimal_y_pred_scale'] = optimal_w * model_dataframe['x_scaled']  # Generate predictions using optimal_w
axes[0].plot(model_dataframe['x_scaled'], model_dataframe['optimal_y_pred_scale'], color='red', label=f'Best Fit Line (w={optimal_w:.4f})', linewidth=2)
axes[0].set_xlabel('Scaled GrLivArea (Living Area)')
axes[0].set_ylabel('Scaled SalePrice')
axes[0].set_title('Scatter Plot with Best Fit Line (Using Gradient Descent on Scaled Data)')
axes[0].legend()
axes[0].grid(True)

# Second Plot: MSE vs Slope (w)
axes[1].plot(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], marker='o', color='green', label='MSE vs Slope (w)')
axes[1].scatter(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], color='red')
axes[1].axhline(y=min_mse, color='blue', linestyle='--', label=f'Minimum MSE = {min_mse:.4f}')
axes[1].set_title(r'$J(w, b)$ vs Slope (w)')
axes[1].set_xlabel(r'Slope $(w)$')
axes[1].set_ylabel(r'$J(w, b)$')  # Using Latex for the y-axis title
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# --------------------------------------------------------------------------------
# Scaled Slope value is: 0.71
# --------------------------------------------------------------------------------

# %% [markdown]
# - Equation to scale back slope w value
# - $\boxed{\color{blue}{\boldsymbol{w_{\text{original}} = w_{\text{scaled}} \times \frac{\text{std}(y)}{\text{std}(x)}}}}$

# %%
# Undo scaling to revert slope to original scale
w_original = optimal_w * (model_dataframe['y'].std() / model_dataframe['x'].std())

print(f"Original Slope (w): {w_original}")
# Out:
# Original Slope (w): 107.0290641298944

# %%
# y = m * x + c where x is df_train_ref['GrLiveArea']
w = w_original
b = 0
y = w * df_train_refined['GrLivArea'] + b
df_train_refined.plot(kind='scatter', x='GrLivArea', y='SalePrice', marker='x')
plt.plot(df_train_refined['GrLivArea'], y, c='red')
plt.title('Drawing Straigh line through datapoints');

# %% [markdown]
# - Application of cost funtion derivation in Python
# - $\boxed{\color{blue}{\boldsymbol{J(w, b) = \frac{1}{2m} \sum_{i=1}{(i)} - y^{(i)} \big)^2}}}$
# - gradient = 2 * ((model_dataframe['x_scaled'] * ((w * model_dataframe['x_scaled']) - model_dataframe['y_scaled'])).mean())

# %% [markdown]
# # __Data set split between train, test and validation data__
# - Splitting data ensures fair evaluation, reduces bias, and helps assess the model's generalization ability.
# - Training data is used to teach the algorithm patterns and relationships in the dataset.
# - Testing data evaluates how well the algorithm generalizes to unseen examples for accuracy.
# - Validation data helps fine-tune the model by comparing predictions with actual values.
# - Randomizing the data using shuffling ensures unbiased and even distribution across subsets.
# - Resetting the dataset removes inconsistencies, providing a clean slate for reliable model training.
# - Using a basic algorithm and achieving reasonable predictions is a significant and motivating milestone.

# %%
# Define the total count of the data and the proportions
total_count = model_dataframe.shape[0]
training_count = int(total_count * 0.80)  # 80% for training
testing_count = int(total_count * 0.15)  # 15% for testing
validation_count = total_count - training_count - testing_count  # Remaining 5% for validation

# Create a horizontal bar chart
fig, ax = plt.subplots(figsize=(10, 2))
ax.barh([0], training_count, color='blue', label='Training Data')  # Training data in blue
ax.barh([0], testing_count, color='orange', left=training_count, label='Testing Data')  # Testing data in orange
ax.barh([0], validation_count, color='green', left=training_count+testing_count, label='Validation Data')  # Validation data in green

# Add labels inside the bars
ax.text(training_count / 2, 0, '80%', ha='center', va='center', color='white', fontsize=10)  # Training data label
ax.text(training_count + testing_count / 2, 0, '15%', ha='center', va='center', color='black', fontsize=10)  # Testing data label
ax.text(training_count + testing_count + validation_count / 2, 0, '5%', ha='center', va='center', color='black', fontsize=10)  # Validation data label

# Add axis labels and title
ax.set_xlim(0, total_count)
ax.set_yticks([0])
ax.set_yticklabels(['Data Split'])
ax.set_xlabel('Count')
ax.set_title('Data Split Visualization')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=3)

# Show the plot
plt.show()

# %%
# Resetting the dataset
del(model_dataframe)
model_dataframe = df_train_refined[['GrLivArea', 'SalePrice']].rename(columns = {
    'GrLivArea': 'x',
    'SalePrice': 'y'})

# Calculate scaled values
model_dataframe['x_scaled'] = (model_dataframe['x'] - model_dataframe['x'].mean()) / model_dataframe['x'].std()
model_dataframe['y_scaled'] = (model_dataframe['y'] - model_dataframe['y'].mean()) / model_dataframe['y'].std()

model_dataframe.head()
# Out:
#       x       y  x_scaled  y_scaled
# 0  1710  208500  0.370207  0.347154
# 1  1262  181500 -0.482347  0.007286
# 2  1786  223500  0.514836  0.535970
# 3  1717  140000  0.383528 -0.515105
# 4  2198  250000  1.298881  0.869545

# %%
# Shuffle the dataset manually
shuffled_dataframe = model_dataframe.sample(frac=1, random_state=42).reset_index(drop=True)

# Calculate the sizes for training, testing, and validation
total_count = len(shuffled_dataframe)
training_count = int(total_count * 0.80)  # 80% for training
testing_count = int(total_count * 0.15)  # 15% for testing
validation_count = total_count - training_count - testing_count  # Remaining 5% for validation

# Split the data explicitly using .copy() to avoid SettingWithCopyWarning
training_data = shuffled_dataframe.iloc[:training_count].copy()
testing_data = shuffled_dataframe.iloc[training_count:training_count + testing_count].copy()
validation_data = shuffled_dataframe.iloc[training_count + testing_count:].copy()

# Display the sizes of each subset
print(f"Training Data: {len(training_data)} rows")
print(f"Testing Data: {len(testing_data)} rows")
print(f"Validation Data: {len(validation_data)} rows")

# Optionally, view the first few rows of each subset
print("\nTraining Data Sample:")
print(training_data.head())
print("\nTesting Data Sample:")
print(testing_data.head())
print("\nValidation Data Sample:")
print(validation_data.head())
# Out:
# Training Data: 1168 rows
# Testing Data: 219 rows
# Validation Data: 73 rows
#
# Training Data Sample:
#       x       y  x_scaled  y_scaled
# 0  1068  154500 -0.851533 -0.332583
# 1  2622  325000  2.105761  1.813624
# 2  1028  115000 -0.927653 -0.829798
# 3  1664  159000  0.282668 -0.275938
# 4  1620  315500  0.198935  1.694040
#
# Testing Data Sample:
#          x       y  x_scaled  y_scaled
# 1168  1635  210000  0.227480  0.366036
# 1169  1458   97500 -0.109355 -1.050083
# 1170  1224  165000 -0.554661 -0.200412
# 1171  1506  213490 -0.018010  0.409967
# 1172  2136  137900  1.180893 -0.541539
#
# Validation Data Sample:
#          x       y  x_scaled  y_scaled
# 1387  1310  164990 -0.391002 -0.200537
# 1388  2576  361919  2.018222  2.278350
# 1389   936  140000 -1.102731 -0.515105
# 1390  1647  128000  0.250316 -0.666157
# 1391  1220  194000 -0.562274  0.164632

# %%
# Gradient Descent Parameters
learning_rate = 0.9  # Reduced learning rate for stability
iterations = 50  # Increased iterations for smoother convergence
w = -50  # Start with a small slope value
b = 0  # Intercept remains constant
gradient_descent_history = []  # To store w values and corresponding MSE during gradient descent

# Perform Gradient Descent
for _ in range(iterations):
    # Generate predicted values based on current slope (w)
    training_data['y_pred_scale'] = w * training_data['x_scaled'] + b

    # Calculate Gradient (dMSE/dw)
    gradient = 2 * ((training_data['x_scaled'] * (w * training_data['x_scaled'] - training_data['y_scaled'])).mean())

    # Update w using gradient descent formula
    w = w - learning_rate * gradient

    # Calculate Mean Squared Error
    mse = ((training_data['y_pred_scale'] - training_data['y_scaled']) ** 2).mean()
    gradient_descent_history.append((w, mse))  # Store slope and corresponding MSE

# Convert Gradient Descent History to DataFrame
gradient_descent_df = pd.DataFrame(
    gradient_descent_history,
    columns=['Slope (w)', 'Mean Squared Error']
)

# Sort the gradient_descent_df by Slope (w) for proper plotting
gradient_descent_df = gradient_descent_df.sort_values(by='Slope (w)')

# Find the most optimal slope (w) and corresponding mean squared error
optimal_w = gradient_descent_df.loc[gradient_descent_df['Mean Squared Error'].idxmin(), 'Slope (w)']
min_mse = gradient_descent_df['Mean Squared Error'].min()
print('-' * 80)
print(f'Scaled Slope value is: {optimal_w:.2f}')
print('-' * 80)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# First Plot: Scatter Plot with Best Fit Line
axes[0].scatter(training_data['x_scaled'], training_data['y_scaled'], color='blue', label='Actual Data')
training_data['optimal_y_pred_scale'] = optimal_w * training_data['x_scaled']  # Generate predictions using optimal_w
axes[0].plot(training_data['x_scaled'], training_data['optimal_y_pred_scale'], color='red', label=f'Best Fit Line (w={optimal_w:.4f})', linewidth=2)
axes[0].set_xlabel('Scaled GrLivArea (Living Area)')
axes[0].set_ylabel('Scaled SalePrice')
axes[0].set_title('Scatter Plot with Best Fit Line (Using Gradient Descent on Scaled Data)')
axes[0].legend()
axes[0].grid(True)

# Second Plot: J(w, b) vs Slope (w)
axes[1].plot(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], marker='o', color='green', label=r'$J(w, b)$ vs Slope (w)')
axes[1].scatter(gradient_descent_df['Slope (w)'], gradient_descent_df['Mean Squared Error'], color='red')
axes[1].axhline(y=min_mse, color='blue', linestyle='--', label=f'Minimum $J(w, b)$ = {min_mse:.4f}')
axes[1].set_title(r'$J(w, b)$ vs Slope (w)')
axes[1].set_xlabel(r'Slope $(w)$')
axes[1].set_ylabel(r'$J(w, b)$')  # Using Latex for the y-axis title
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# --------------------------------------------------------------------------------
# Scaled Slope value is: 0.68
# --------------------------------------------------------------------------------

# %%
# Undo scaling to revert slope to original scale
w_original = optimal_w * (model_dataframe['y'].std() / model_dataframe['x'].std())

print(f"Original Slope (w): {w_original}")
# Out:
# Original Slope (w): 102.1717165126447

# %%
# Generate predictions for testing data using the original slope (w_original) and intercept (b)
testing_data['y_pred'] = w_original * testing_data['x']

# Visualization: Scatter Plot and Best Fit Line for Testing Data
plt.figure(figsize=(10, 6))

# Scatter plot for actual data points
plt.scatter(testing_data['x'], testing_data['y'], color='blue', label='Actual Testing Data')

# Best fit line using original slope
plt.plot(testing_data['x'], testing_data['y_pred'], color='red', label=f'Best Fit Line (w={w_original:.4f})', linewidth=2)

# Labels and title
plt.xlabel('GrLivArea (Living Area)')
plt.ylabel('SalePrice')
plt.title('Testing Data: Actual vs Predicted (Using Original Slope)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Select a few samples from the validation data
sample_validation_data = validation_data.sample(5, random_state=42)  # Randomly select 5 samples

# Calculate the predicted values for the selected samples using the original slope and intercept
sample_validation_data['y_pred'] = w_original * sample_validation_data['x']

# Compare the actual values with the predicted values
comparison = sample_validation_data[['x', 'y', 'y_pred']]

# Display the comparison
print("Validation Data Comparison (Actual vs Predicted):")
print(comparison)

# Optionally, calculate the differences for better understanding
sample_validation_data['difference'] = sample_validation_data['y'] - sample_validation_data['y_pred']
print("\nDifferences (Actual - Predicted):")
print(sample_validation_data[['x', 'difference']])
# Out:
# Validation Data Comparison (Actual vs Predicted):
#          x       y         y_pred
# 1391  1220  194000  124649.494145
# 1450  1728  119000  176552.726134
# 1405  1614  221500  164905.150451
# 1387  1310  164990  133844.948632
# 1415  1048   98300  107075.958905
#
# Differences (Actual - Predicted):
#          x    difference
# 1391  1220  69350.505855
# 1450  1728 -57552.726134
# 1405  1614  56594.849549
# 1387  1310  31145.051368
# 1415  1048  -8775.958905

# %% [markdown]
# # __Multi variable regression__
# - Gradient descent will now be applied across multiple features, moving beyond single-feature modeling.
# - Each feature will have its own slope, denoted as w, resulting in n slopes for n features.
# - The same weight, w, will be consistently applied to all values within a single feature.
# - The bias, b, will remain a single value shared across all features and data points.
# - Our notation has been expanded to accommodate and represent this extended set of information.

# %%
multi_feature1 = ['GrLivArea', 'GarageArea', 'SalePrice']
df_multi_feature1 = df_train_refined[multi_feature1].copy()

# %% [markdown]
# ## __Mathematical Notation__
# * $\mathbf{x}^{i}_{j}$ where $\mathbf{i} = 1, 2, 3, \ldots, m \quad \text{and} \quad \mathbf{j} = 1, 2, 3, \ldots, n$
# * Each feature will have its own slope $\mathbf{w}$ which are $\mathbf{w_1, w_2, w_3, ... w_n}$
#
# * __Table: Representation of Features and Predictions__
#
# | #   | $x_{1}$          | $x_{2}$          | ...          | $x_{n}$          | $y$          | $y_{\text{predict}}$                                                    |
# |-----|------------------|------------------|--------------|------------------|--------------|------------------------------------------------------------------------|
#               |
# | 1   | $x_{1}^{1}$      | $x_{2}^{1}$      | ...          | $x_{n}^{1}$      | $y^{1}$      | $w_1x_{1}^{1} + w_2x_{2}^{1} + \dots + w_nx_{n}^{1} + b$               |
# | 2   | $x_{1}^{2}$      | $x_{2}^{2}$      | ...          | $x_{n}^{2}$      | $y^{2}$      | $w_1x_{1}^{2} + w_2x_{2}^{2} + \dots + w_nx_{n}^{2} + b$               |
# | ... | $x_{1}^{\dots}$  | $x_{2}^{\dots}$  | ...          | $x_{n}^{\dots}$  | $y^{\dots}$  | $w_1x_{1}^{\dots} + w_2x_{2}^{\dots} + \dots + w_nx_{n}^{\dots} + b$   |
# | $m$ | $x_{1}^{m}$   | $x_{2}^{m}$   | ...          | $x_{n}^{m}$    | $y^{m}$    | $w_1x_{1}^{m} + w_2x_{2}^{m} + \dots + w_nx_{n}^{m} + b$         |

# %% [markdown]
# ## __Python based Notations__
# * $\mathbf{x}^{i}_{j}$ where $\mathbf{i} = 0, 1, 2, \ldots, m - 1 \quad \text{and} \quad \mathbf{j} = 0, 1, 2, \ldots, n - 1 $
# * Each feature will have its own slope $\mathbf{w}$ which are $\mathbf{w_0, w_1, w_2, ... w_{n-1}}$
#
# | #   | $x_{0}$          | $x_{1}$          | ...          | $x_{n-1}$        | $y$          | $y_{\text{predict}}$                                     |
# |-----|------------------|------------------|--------------|------------------|--------------|--------------------------------------------------------|
# | 0   | $x_{0}^{0}$      | $x_{1}^{0}$      | ...          | $x_{n-1}^{0}$    | $y^{0}$      | $w_{0}x_{0}^{0} + w_{1}x_{1}^{0} + ... + w_{n-1}x_{n-1}^{0} + b$ |
# | 1   | $x_{0}^{1}$      | $x_{1}^{1}$      | ...          | $x_{n-1}^{1}$    | $y^{1}$      | $w_{0}x_{0}^{1} + w_{1}x_{1}^{1} + ... + w_{n-1}x_{n-1}^{1} + b$ |
# | 2   | $x_{0}^{2}$      | $x_{1}^{2}$      | ...          | $x_{n-1}^{2}$    | $y^{2}$      | $w_{0}x_{0}^{2} + w_{1}x_{1}^{2} + ... + w_{n-1}x_{n-1}^{2} + b$ |
# | ... | $x_{0}^{\dots}$  | $x_{1}^{\dots}$  | ...          | $x_{n-1}^{\dots}$| $y^{\dots}$  | $w_{0}x_{0}^{\dots} + w_{1}x_{1}^{\dots} + ... + w_{n-1}x_{n-1}^{\dots} + b$ |
# | $m-1$ | $x_{0}^{m-1}$   | $x_{1}^{m-1}$   | ...          | $x_{n-1}^{m-1}$  | $y^{m-1}$    | $w_{0}x_{0}^{m-1} + w_{1}x_{1}^{m-1} + ... + w_{n-1}x_{n-1}^{m-1} + b$ |

# %%
# Rename columns in df_multi_feature1
df_multi_feature1 = df_multi_feature1.rename(columns={
    'GrLivArea': 'x0',
    'GarageArea': 'x1',
    'SalePrice': 'y',
})
df_multi_feature1.head()
# Out:
#      x0   x1       y
# 0  1710  548  208500
# 1  1262  460  181500
# 2  1786  608  223500
# 3  1717  642  140000
# 4  2198  836  250000

# %%
for col in df_multi_feature1.columns:
    df_multi_feature1[col+'_scaled'] = (df_multi_feature1[col] - df_multi_feature1[col].mean())/df_multi_feature1[col].std()

df_multi_feature1.head()
# Out:
#      x0   x1       y  x0_scaled  x1_scaled  y_scaled
# 0  1710  548  208500   0.370207   0.350880  0.347154
# 1  1262  460  181500  -0.482347  -0.060710  0.007286
# 2  1786  608  223500   0.514836   0.631510  0.535970
# 3  1717  642  140000   0.383528   0.790533 -0.515105
# 4  2198  836  250000   1.298881   1.697903  0.869545

# %%
# Gradient Descent Parameters
learning_rate = 0.1  # Learning rate
iterations = 200  # Number of iterations
gradient_descent_history = []  # To track MSE during training

# Initialize weights for features (w0 and w1) and bias (b)
w0 = -50  # Initial weight for feature x0_scaled
w1 = -50  # Initial weight for feature x1_scaled
b = 0  # Bias term

# Initialize variables to track the best weights, bias, and lowest MSE
best_w0 = w0
best_w1 = w1
best_b = b
lowest_mse = float('inf')  # Start with an infinitely large MSE

# Perform Gradient Descent
for _ in range(iterations):
    # Calculate predictions for all rows in the dataset
    df_multi_feature1['y_pred_scaled'] = (
        df_multi_feature1['x0_scaled'] * w0 +
        df_multi_feature1['x1_scaled'] * w1 +
        b
    )

    # Calculate errors
    df_multi_feature1['error'] = (
        df_multi_feature1['y_pred_scaled'] - df_multi_feature1['y_scaled']
    )

    # Update weights for each feature
    gradient_w0 = 2 * (df_multi_feature1['error'] * df_multi_feature1['x0_scaled']).mean()
    w0 -= learning_rate * gradient_w0

    gradient_w1 = 2 * (df_multi_feature1['error'] * df_multi_feature1['x1_scaled']).mean()
    w1 -= learning_rate * gradient_w1

    # Update bias term
    gradient_b = 2 * df_multi_feature1['error'].mean()
    b -= learning_rate * gradient_b

    # Calculate Mean Squared Error (MSE)
    mse = (df_multi_feature1['error'] ** 2).mean()

    # Update best weights and bias if the current MSE is the lowest
    if mse < lowest_mse:
        lowest_mse = mse
        best_w0 = w0
        best_w1 = w1
        best_b = b

# Recalculate y_pred using the best weights and bias after all iterations
df_multi_feature1['y_pred_best'] = (
    df_multi_feature1['x0_scaled'] * best_w0 +
    df_multi_feature1['x1_scaled'] * best_w1 +
    best_b
)

# Output the best weights, bias, and the lowest MSE
print("Best weight w0:", best_w0)
print("Best weight w1:", best_w1)
print("Best bias b:", best_b)
print("Lowest MSE:", lowest_mse)
# Out:
# Best weight w0: 0.5336084991511256
# Best weight w1: 0.3731704008089294
# Best bias b: 1.9637259854739762e-16
# Lowest MSE: 0.38895920279038126

# %%
df_multi_feature1['y_pred']  = (df_multi_feature1['y_pred_best'] * df_multi_feature1['y'].std()) + df_multi_feature1['y'].mean()

# %%
df_multi_feature1[['y', 'y_pred']].head(10)
# Out:
#         y         y_pred
# 0  208500  207016.743231
# 1  181500  158674.155385
# 2  223500  221467.198144
# 3  140000  220615.223640
# 4  250000  286317.633103
# 5  143000  169514.432046
# 6  307000  217927.839862
# 7  200000  228797.780008
# 8  129900  201087.127802
# 9  118000  108392.363787

# %% [markdown]
# # __Dot product__
# - The __dot product__ simplifies calculations, combining feature inputs and weights into a single scalar.
# - Gradient descent algorithm works more efficiently with additional features, but calculations grow complex with traditional methods.
# - The dot product simplifies weight-feature calculations, enhancing computational speed and mathematical efficiency.
# - Weight vector ( w ) represents feature importance; feature vector \(x\) holds scaled input data.
# - Dot product is vital in linear models, summing weighted contributions into a single scalar value.
# - Python stores weight vectors as column-like structures, reversing dot product order compared to mathematics.
# - Fixing vector dimensions during dot/matrix multiplication is critical for mastering machine learning techniques.
# - Applying these methods to gradient descent boosts prediction accuracy and strengthens workflow confidence.

# %%
multi_feature2 = ['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'MasVnrArea', 'BsmtFinSF1', 'LotFrontage', 'SalePrice']
df_multi_feature2 = df_train_refined[multi_feature2].copy()
df_multi_feature2.columns = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'y']
# Scale all columns in df_multi_feature2 using a loop
for col in df_multi_feature2.columns:
    mean = df_multi_feature2[col].mean()  # Calculate mean of the column
    std = df_multi_feature2[col].std()    # Calculate standard deviation of the column
    df_multi_feature2[col + '_scaled'] = (df_multi_feature2[col] - mean) / std  # Apply Z-score formula

# Print the scaled DataFrame
df_multi_feature2.head()
# Out:
#      x1   x2    x3    x4     x5   x6    x7       y  x1_scaled  x2_scaled  \
# 0  1710  548   856   856  196.0  706  65.0  208500   0.370207   0.350880
# 1  1262  460  1262  1262    0.0  978  80.0  181500  -0.482347  -0.060710
# 2  1786  608   920   920  162.0  486  68.0  223500   0.514836   0.631510
# 3  1717  642   756   961    0.0  216  60.0  140000   0.383528   0.790533
# 4  2198  836  1145  1145  350.0  655  84.0  250000   1.298881   1.697903
#
#    x3_scaled  x4_scaled  x5_scaled  x6_scaled  x7_scaled  y_scaled
# 0  -0.459145  -0.793162   0.513928   0.575228  -0.220799  0.347154
# 1   0.466305   0.257052  -0.570555   1.171591   0.460162  0.007286
# 2  -0.313261  -0.627611   0.325803   0.092875  -0.084607  0.535970
# 3  -0.687089  -0.521555  -0.570555  -0.499103  -0.447787 -0.515105
# 4   0.199611  -0.045596   1.366021   0.463410   0.641752  0.869545

# %%
# Gradient Descent Parameters
learning_rate = 0.1  # Learning rate
iterations = 200  # Number of iterations
gradient_descent_history = []  # To track MSE during training

# Initialize weights for each feature and bias (b)
weights = {f'w{i+1}': -50 for i in range(7)}  # Initialize w1 to w7 with -50
b = 0  # Bias term

# Initialize variables to track the best weights, bias, and lowest MSE
best_weights = weights.copy()  # Copy the initial weights as the best weights
best_b = b
lowest_mse = float('inf')  # Start with an infinitely large MSE

# Perform Gradient Descent
for _ in range(iterations):
    # Calculate predictions for all rows in the dataset
    df_multi_feature2['y_pred_scaled'] = sum(
        df_multi_feature2[f'x{i+1}_scaled'] * weights[f'w{i+1}'] for i in range(7)
    ) + b

    # Calculate errors
    df_multi_feature2['error'] = (
        df_multi_feature2['y_pred_scaled'] - df_multi_feature2['y_scaled']
    )

    # Update weights for each feature
    for i in range(7):  # Iterate over all features
        gradient_w = 2 * (df_multi_feature2['error'] * df_multi_feature2[f'x{i+1}_scaled']).mean()
        weights[f'w{i+1}'] -= learning_rate * gradient_w

    # Update bias term
    gradient_b = 2 * df_multi_feature2['error'].mean()
    b -= learning_rate * gradient_b

    # Calculate Mean Squared Error (MSE)
    mse = (df_multi_feature2['error'] ** 2).mean()

    # Update best weights and bias if the current MSE is the lowest
    if mse < lowest_mse:
        lowest_mse = mse
        best_weights = weights.copy()
        best_b = b

# Recalculate y_pred using the best weights and bias after all iterations
df_multi_feature2['y_pred_best'] = sum(
    df_multi_feature2[f'x{i+1}_scaled'] * best_weights[f'w{i+1}'] for i in range(7)
) + best_b

# Output the best weights, bias, and the lowest MSE
print("Best weights:", best_weights)
print("Best bias b:", best_b)
print("Lowest MSE:", lowest_mse)

df_multi_feature2['y_pred']  = (df_multi_feature2['y_pred_best'] * df_multi_feature2['y'].std()) + df_multi_feature2['y'].mean()
df_multi_feature2.head()
# Out:
# Best weights: {'w1': np.float64(0.446654629934082), 'w2': np.float64(0.2553459088765033), 'w3': np.float64(0.23556770962048407), 'w4': np.float64(-0.031152516703204538), 'w5': np.float64(0.1125267741105762), 'w6': np.float64(0.08398598719501607), 'w7': np.float64(-0.023030592249525146)}
# Best bias b: 1.5305869205243156e-16
# Lowest MSE: 0.3204582693883224
#      x1   x2    x3    x4     x5   x6    x7       y  x1_scaled  x2_scaled  \
# 0  1710  548   856   856  196.0  706  65.0  208500   0.370207   0.350880
# 1  1262  460  1262  1262    0.0  978  80.0  181500  -0.482347  -0.060710
# 2  1786  608   920   920  162.0  486  68.0  223500   0.514836   0.631510
# 3  1717  642   756   961    0.0  216  60.0  140000   0.383528   0.790533
# 4  2198  836  1145  1145  350.0  655  84.0  250000   1.298881   1.697903
#
#    x3_scaled  x4_scaled  x5_scaled  x6_scaled  x7_scaled  y_scaled  \
# 0  -0.459145  -0.793162   0.513928   0.575228  -0.220799  0.347154
# ...

# %% [markdown]
# * $\mathbf{w \text{ and } x}$ in vector form
#   * $\vec{\mathbf{w}} = \mathbf[{w_1, w_2, w_3, \dots, w_n}]$
#   * $\vec{\mathbf{x}} = \mathbf{[x_1, x_2, x_3, \dots, x_n]}$
#
# * dot product of $\mathbf{w \text{ and } x}$
#   * $\vec{\mathbf{w}} \cdot \vec{\mathbf{x}} = [w_1 x_1 + w_2 x_2 + \dots + w_n x_n]$

# %%
# Define the weight vector w as a Pandas Series
w = pd.Series([2, 4, 6, 8], index=['Feature1', 'Feature2', 'Feature3', 'Feature4'])

# Define the feature matrix x as a DataFrame
data = {
    'Feature1': [1],
    'Feature2': [3],
    'Feature3': [5],
    'Feature4': [7]
}
x = pd.DataFrame(data)

# Compute the dot product using Pandas' dot method
# dot product is [2*1 + 4*3 + 6*5 + 8*7]
x['Dot_Product'] = x.dot(w)

# Print the DataFrame with the dot product column
x
# Out:
#    Feature1  Feature2  Feature3  Feature4  Dot_Product
# 0         1         3         5         7          100

# %%
def plot_mse_vs_iterations(mse_history):
    """
    Plots MSE vs Iterations.

    This function creates a line plot to visualize the progression of the
    Mean Squared Error (MSE) over the iterations of gradient descent.

    Parameters:
    mse_history : numpy.ndarray
        The Mean Squared Error values recorded across all iterations of gradient descent.

    Returns:
    None
        Displays the plot of MSE vs Iterations.
    """
    iterations = range(1, len(mse_history) + 1)  # Create iteration numbers (1-based indexing)

    plt.figure(figsize=(8, 6))
    plt.plot(iterations, mse_history, marker='o', linestyle='-', color='blue')
    plt.xlabel("Iterations", fontsize=12)
    plt.ylabel("Mean Squared Error (MSE)", fontsize=12)
    plt.title("MSE vs Iterations", fontsize=14)
    plt.grid()
    plt.show()

# %%
def linear_regression(data, learning_rate=0.1, training_iter=100, w_initail=-50.0, verbose=False):
    """
    Performs linear regression using gradient descent and returns unscaled predictions (y_pred).

    This function applies gradient descent to find the optimal weights and bias
    for a given dataset. It includes feature scaling, dynamically tracks the
    history of weights, bias, and MSE during the training process, and calculates
    unscaled predictions using the best weights and bias.

    Parameters:
    data : pandas.DataFrame
        The input dataset containing features and the target column.
    learning_rate : float, optional (default=0.1)
        The step size used for updating weights and bias during gradient descent.
    training_iter : int, optional (default=100)
        The number of iterations to run the gradient descent process.

    Returns:
    tuple:
        - best_w : numpy.ndarray
            The best weights obtained at the iteration with the lowest MSE.
        - best_b : float
            The best bias obtained at the iteration with the lowest MSE.
        - best_mse : float
            The lowest Mean Squared Error achieved during training.
        - y_pred : numpy.ndarray
            The unscaled predictions based on the best weights and bias.
    """
    df_x = data.copy()

    # Reset DataFrame if 'y_pred' exists

    df_x = df_x.loc[:, ~df_x.columns.str.contains('_pred')]
    target = df_x.columns[-1]

    data_dim = df_x.shape

    # Feature scaling
    for col in df_x.columns:
        df_x[col + '_scaled'] = (df_x[col] - df_x[col].mean()) / df_x[col].std()

    w = np.full((data_dim[1] - 1), w_initail)

    if verbose:
        print(f'{w=}')

    b = 0

    w_history = np.zeros((training_iter, data_dim[1] - 1))  # Store weights (iterations, features)
    b_history = np.zeros(training_iter)  # Store bias values
    mse_history = np.zeros(training_iter)  # Store MSE values


    # Select columns with '_scaled' in their name except the last column
    features = df_x.columns[df_x.columns.str.contains('_scaled')][:-1]
    target_scaled = df_x.columns[df_x.columns.str.contains('_scaled')][-1]

    # Gradient descent
    for iteration in range(training_iter):

        df_x[target+'_pred_scaled'] = df_x[features].dot(w) + b  # Compute scaled predictions
        df_x['error'] = df_x[target+'_pred_scaled'] - df_x[target+'_scaled']  # Compute error

        w_gradients = 2 * df_x['error'].dot(df_x[features].values) / data_dim[0]
        b_gradients = 2 * df_x['error'].mean()

        # Update weights and bias
        w -= learning_rate * w_gradients
        b -= learning_rate * b_gradients
        mse = (df_x['error'] ** 2).mean()

        if verbose:
            print(f"{df_x[['error',target+'_pred_scaled']].head()=}")
            print(f'{w_gradients=}')
            print(f'{b_gradients=}')
            print(f'{w=}')
            print(f'{b=}')
            print(f'{mse=}')

        w_history[iteration] = w
        b_history[iteration] = b
        mse_history[iteration] = mse

    # Find best parameters
    best_index = np.argmin(mse_history)
    best_w = w_history[best_index]
    best_b = b_history[best_index]
    best_mse = mse_history[best_index]

    # Compute scaled predictions for the target variable
    df_x[target+'_pred_scaled'] = df_x[features].dot(best_w) + best_b

    # Compute unscaled predictions
    y_mean = data[target].mean()  # Mean of original target column
    y_std = data[target].std()    # Standard deviation of original target column
    y_pred = ((df_x[target+'_pred_scaled'] * y_std) + y_mean).astype('int')  # Unscale predictions as int

    if verbose:
        print(df_x.head())

    # Plot MSE vs Iterations
    plot_mse_vs_iterations(mse_history)

    return best_w, best_b, best_mse, y_pred

# %%
multi_feature2 = ['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'MasVnrArea', 'BsmtFinSF1', 'LotFrontage', 'SalePrice']
df_multi_feature21 = df_train_refined[multi_feature2].copy()

best_w, best_b, best_mse, df_multi_feature21['SalePrice_pred'] = linear_regression(df_multi_feature21, learning_rate=0.1, training_iter=200)
print(best_w, best_b, best_mse)
df_multi_feature21[['SalePrice', 'SalePrice_pred']].head()
# Out:
# [ 0.44665463  0.25534591  0.23556771 -0.03115252  0.11252677  0.08398599
#  -0.02303059] 1.477052878788974e-16 0.3204582693883224
#    SalePrice  SalePrice_pred
# 0     208500          203381
# 1     181500          172539
# 2     223500          211377
# 3     140000          191387
# 4     250000          279429

# %% [markdown]
# # __House price prediction with full application__
# - Applied exploratory data analysis to identify 30 features significantly affecting house sale prices.
# - Replaced string values with numerical ones to prepare data for linear regression modeling.
# - Checked and handled null values, dropping insignificant features and the Electrical row with NaN.
# - Final dataset prepared with 28 features and 1 target column, ready for linear regression.
# - Ran linear regression model; results are promising yet not perfect for a basic algorithm.
# - Emphasized importance of domain knowledge, Google, or ChatGPT for refining analysis processes.
# - Committed to advanced exploration for achieving expert-level skills and utilizing superior algorithms.

# %%
data_desc = 'data_description.txt'

# Open Data Description file
with open(data_desc, 'r', encoding='utf-8') as meta_data:
    data_info = meta_data.readlines()

# %%
def extract_feature_info(feature_name, file_lines):
    """
    Extracts the description and details of a specified feature from a list of file lines.

    Parameters:
        feature_name (str): The name of the feature to extract.
        file_lines (list): The lines of the file as a list of strings.

    Returns:
        tuple: A tuple containing the feature description (str) and details (str).
    """
    description = None
    details = []  # To collect lines with feature details
    is_feature_section = False

    for idx, line in enumerate(file_lines):
        line = line.rstrip()  # Remove trailing whitespace

        # Check if the line is the feature name
        if line.startswith(f"{feature_name}:"):
            # Extract the description for the feature
            description = line.split(":", 1)[1].strip()
            is_feature_section = True  # Start capturing details from subsequent lines
            continue

        # If capturing details, stop when encountering a new feature
        if is_feature_section:
            # A new feature starts if ":" is present AND the line does NOT start with a space
            if ":" in line and not line.startswith(" "):
                break

            # Otherwise, add non-empty lines to details
            if line.strip():  # Skip empty lines
                details.append(line.strip())

    # Combine details into a single string with proper formatting
    details_str = "\n".join(details)
    return feature_name, description, details_str

# %%
df_train_refined.iloc[:5,:18]
# Out:
#    Id  LotFrontage  LotArea Neighborhood  OverallQual  YearBuilt  \
# 0   1         65.0     8450      CollgCr            7       2003
# 1   2         80.0     9600      Veenker            6       1976
# 2   3         68.0    11250      CollgCr            7       2001
# 3   4         60.0     9550      Crawfor            7       1915
# 4   5         84.0    14260      NoRidge            8       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual Foundation  BsmtQual  BsmtFinSF1  \
# 0          2003       196.0          4      PConc       4.0         706
# 1          1976         0.0          3     CBlock       4.0         978
# 2          2002       162.0          4      PConc       4.0         486
# 3          1970         0.0          3     BrkTil       3.0         216
# 4          2000       350.0          4      PConc       4.0         655
#
#    BsmtUnfSF  TotalBsmtSF  HeatingQC CentralAir Electrical  1stFlrSF
# 0        150          856          5          Y      SBrkr       856
# ...

# %%
feature_name, feature_description, feature_details = extract_feature_info('Neighborhood', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
# Out:
# Neighborhood : Physical locations within Ames city limits
# Blmngtn	Bloomington Heights
# Blueste	Bluestem
# BrDale	Briardale
# BrkSide	Brookside
# ClearCr	Clear Creek
# CollgCr	College Creek
# Crawfor	Crawford
# Edwards	Edwards
# Gilbert	Gilbert
# IDOTRR	Iowa DOT and Rail Road
# MeadowV	Meadow Village
# Mitchel	Mitchell
# Names	North Ames
# NoRidge	Northridge
# NPkVill	Northpark Villa
# NridgHt	Northridge Heights
# NWAmes	Northwest Ames
# OldTown	Old Town
# SWISU	South & West of Iowa State University
# Sawyer	Sawyer
# SawyerW	Sawyer West
# Somerst	Somerset
# StoneBr	Stone Brook
# Timber	Timberland
# Veenker	Veenker

# %%
df_train_refined.drop(columns='Neighborhood', inplace=True)

# %%
feature_name, feature_description, feature_details = extract_feature_info('Foundation', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
# Out:
# Foundation : Type of foundation
# BrkTil	Brick & Tile
# CBlock	Cinder Block
# PConc	Poured Contrete
# Slab	Slab
# Stone	Stone
# Wood	Wood

# %%
df_train_refined['Foundation'].unique()
# Out:
# array(['PConc', 'CBlock', 'BrkTil', 'Wood', 'Slab', 'Stone'], dtype=object)

# %%
Foundation_mapping = {
    'PConc': 5,
    'CBlock': 2,
    'BrkTil': 3,
    'Wood': 0,
    'Slab': 1,
    'Stone': 4
}

df_train_refined['Foundation'] = df_train_refined['Foundation'].replace(Foundation_mapping)

df_train_refined['Foundation'].unique()
# Out:
# <ipython-input-71-6a926bf82864>:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_refined['Foundation'] = df_train_refined['Foundation'].replace(Foundation_mapping)
# array([5, 2, 3, 0, 1, 4])

# %%
feature_name, feature_description, feature_details = extract_feature_info('CentralAir', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
df_train_refined['CentralAir'].unique()
# Out:
# CentralAir : Central air conditioning
# N	No
# Y	Yes
# array(['Y', 'N'], dtype=object)

# %%
CentralAir_mapping = {
    'Y': 1,
    'N': 0
}
df_train_refined['CentralAir'] = df_train_refined['CentralAir'].replace(CentralAir_mapping)

df_train_refined['CentralAir'].unique()
# Out:
# <ipython-input-73-d635c22c9276>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_refined['CentralAir'] = df_train_refined['CentralAir'].replace(CentralAir_mapping)
# array([1, 0])

# %%
feature_name, feature_description, feature_details = extract_feature_info('Electrical', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
# Out:
# Electrical : Electrical system
# SBrkr	Standard Circuit Breakers & Romex
# FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
# FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
# FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
# Mix	Mixed

# %%
df_train_refined['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
Electrical_mapping = {
    'SBrkr': 4,
    'FuseA': 2,
    'FuseF': 1,
    'FuseP': 0,
    'Mix': 3
}

df_train_refined['Electrical'] = df_train_refined['Electrical'].replace(Electrical_mapping)
df_train_refined['Electrical'].unique()
# Out:
# <ipython-input-76-818a031d6443>:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_refined['Electrical'] = df_train_refined['Electrical'].replace(Electrical_mapping)
# array([ 4.,  1.,  2.,  0.,  3., nan])

# %%
df_train_refined.iloc[:5,:18]
# Out:
#    Id  LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0   1         65.0     8450            7       2003          2003       196.0
# 1   2         80.0     9600            6       1976          1976         0.0
# 2   3         68.0    11250            7       2001          2002       162.0
# 3   4         60.0     9550            7       1915          1970         0.0
# 4   5         84.0    14260            8       2000          2000       350.0
#
#    ExterQual  Foundation  BsmtQual  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  \
# 0          4           5       4.0         706        150          856
# 1          3           2       4.0         978        284         1262
# 2          4           5       4.0         486        434          920
# 3          3           3       3.0         216        540          756
# 4          4           5       4.0         655        490         1145
#
#    HeatingQC  CentralAir  Electrical  1stFlrSF  2ndFlrSF
# ...

# %%
df_train_refined.iloc[:5,18:]
# Out:
#    GrLivArea  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0       1710         2         1             3             1            4
# 1       1262         2         0             3             1            3
# 2       1786         2         1             3             1            4
# 3       1717         1         0             3             1            4
# 4       2198         2         1             4             1            4
#
#    Fireplaces GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 0           0     Attchd       2003.0          RFn           2         548
# 1           1     Attchd       1976.0          RFn           2         460
# 2           1     Attchd       2001.0          RFn           2         608
# 3           1     Detchd       1998.0          Unf           3         642
# 4           1     Attchd       2000.0          RFn           3         836
#
#    WoodDeckSF  OpenPorchSF  SalePrice
# ...

# %%
feature_name, feature_description, feature_details = extract_feature_info('GarageType', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
df_train_refined['GarageType'].unique()
# Out:
# GarageType : Garage location
# 2Types	More than one type of garage
# Attchd	Attached to home
# Basment	Basement Garage
# BuiltIn	Built-In (Garage part of house - typically has room above garage)
# CarPort	Car Port
# Detchd	Detached from home
# NA	No Garage
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
GarageType_mapping = {
    'Attchd': 5,
    'Detchd': 2,
    'BuiltIn': 6,
    'CarPort': 1,
    'Basment': 3,
    '2Types': 4,
    # nan values will remain unchanged
}
df_train_refined['GarageType'] = df_train_refined['GarageType'].replace(GarageType_mapping)
df_train_refined['GarageType'].unique()
# Out:
# <ipython-input-80-401d43e8bba5>:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_refined['GarageType'] = df_train_refined['GarageType'].replace(GarageType_mapping)
# array([ 5.,  2.,  6.,  1., nan,  3.,  4.])

# %%
feature_name, feature_description, feature_details = extract_feature_info('GarageFinish', data_info)
print(f'{feature_name} : {feature_description}')
print(feature_details)
df_train_refined['GarageFinish'].unique()
# Out:
# GarageFinish : Interior finish of the garage
# Fin	Finished
# RFn	Rough Finished
# Unf	Unfinished
# NA	No Garage
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
GarageFinish_mapping = {
    'Fin': 3,   # Finished - Best
    'RFn': 2,   # Rough Finished - Moderate
    'Unf': 1,   # Unfinished - Basic
    'NA': 0     # No Garage - Worst
}
df_train_refined['GarageFinish'] = df_train_refined['GarageFinish'].replace(GarageFinish_mapping)
print(df_train_refined['GarageFinish'].unique())
# Out:
# [ 2.  1.  3. nan]
# <ipython-input-82-f012d0c63f23>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train_refined['GarageFinish'] = df_train_refined['GarageFinish'].replace(GarageFinish_mapping)

# %%
df_train_refined.isnull().sum()
# Out:
# Id               0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# ExterQual        0
# Foundation       0
# BsmtQual         0
# BsmtFinSF1       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# HeatingQC        0
# CentralAir       0
# Electrical       1
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# Fireplaces       0
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# SalePrice        0
# dtype: int64

# %%
df_train_refined.drop(columns=['Id', 'GarageType', 'GarageYrBlt', 'GarageFinish'], inplace=True)

# %%
df_train_refined.dropna(subset=['Electrical'], inplace=True)

# %%
df_train_refined.isnull().sum()
# Out:
# LotFrontage     0
# LotArea         0
# OverallQual     0
# YearBuilt       0
# YearRemodAdd    0
# MasVnrArea      0
# ExterQual       0
# Foundation      0
# BsmtQual        0
# BsmtFinSF1      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# HeatingQC       0
# CentralAir      0
# Electrical      0
# 1stFlrSF        0
# 2ndFlrSF        0
# GrLivArea       0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# KitchenAbvGr    0
# KitchenQual     0
# Fireplaces      0
# GarageCars      0
# GarageArea      0
# WoodDeckSF      0
# OpenPorchSF     0
# SalePrice       0
# dtype: int64

# %%
df_train_refined.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %%
best_w, best_b, best_mse, df_train_refined['SalePrice_pred'] = linear_regression(df_train_refined, learning_rate=0.1, training_iter=200)
print(best_w, best_b, best_mse)
df_train_refined[['SalePrice', 'SalePrice_pred']].head()
# Out:
# [-1.06991993e-02 -1.13780631e-02  1.42186905e-01  5.64610706e-02
#   7.77277574e-02  2.23156452e-01  1.08013171e-01  4.26981714e-02
#   2.27741687e-01 -3.05938080e+00 -3.02167585e+00  3.50338394e+00
#   3.33501908e-02 -3.58858260e-02 -6.91252353e-02 -8.24253058e+00
#  -8.71167141e+00  1.06047814e+01  6.31691112e-02  2.31979862e-03
#  -1.92606745e-03  8.36545491e-02  8.55500881e-02  1.41317432e-01
#   2.46072235e-01 -1.74058052e-02 -3.08732651e-02 -6.31479847e-02] -1.3115089701178545e-15 2.3245716277543997
#    SalePrice  SalePrice_pred
# 0     208500          221453
# 1     181500          153442
# 2     223500          233608
# 3     140000          140186
# 4     250000          281264

# %% [markdown]
# # __Exploring Feature Scaling Methods__
# * Standard Scaling or Z-Score Normalization $\mathbf{X_{\text{scaled}} = \frac{X - \mu}{\sigma}}$  Where ${\mu}$ = mean and ${ \sigma}$ = standard  deviation
# *  Mean normalizatoin $\mathbf{X_{\text{normalized}} = \frac{X - \mu}{X_{\text{max}} - X_{\text{min}}}}$ Where ${\mu}$ = mean
# * Max normalization $\mathbf{X_{\text{normalized}} = \frac{X}{X_{\text{max}}}}$
# * Normal mean normal distribution

# %%
# Generate synthetic data with a perfect Gaussian distribution for smooth bell curve
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=200)  # Normal distribution
data = np.concatenate([data, np.random.uniform(1, 20, size=20)])  # Add small tail
data = np.concatenate([data, np.random.uniform(100, 200, size=20)])  # Add large head

# Apply scaling methods
# Z-Score Normalization
mean_value = np.mean(data)
std_deviation = np.std(data)
z_score_scaled = (data - mean_value) / std_deviation

# Min-Max Scaling
min_value = np.min(data)
max_value = np.max(data)
min_max_scaled = (data - min_value) / (max_value - min_value)

# Max Normalization
max_value = np.max(data)
max_normalized = data / max_value

# Plot the original and scaled distributions
plt.figure(figsize=(14, 10))

# Original Data Density Distribution
plt.subplot(2, 2, 1)
density, bins = np.histogram(data, bins=30, density=True)
plt.plot((bins[:-1] + bins[1:]) / 2, density, color='blue', label="Original Data")
plt.title("Original Data Distribution")
plt.xlabel("Feature Values")
plt.ylabel("Density")
plt.legend()

# Z-Score Normalized Data Density Distribution
plt.subplot(2, 2, 2)
density, bins = np.histogram(z_score_scaled, bins=30, density=True)
plt.plot((bins[:-1] + bins[1:]) / 2, density, color='green', label="Z-Score Normalized Data")
plt.title("Z-Score Normalized Distribution")
plt.xlabel("Feature Values")
plt.ylabel("Density")
plt.legend()

# Min-Max Scaled Data Density Distribution
plt.subplot(2, 2, 3)
density, bins = np.histogram(min_max_scaled, bins=30, density=True)
plt.plot((bins[:-1] + bins[1:]) / 2, density, color='orange', label="Min-Max Scaled Data")
plt.title("Min-Max Scaled Distribution")
plt.xlabel("Feature Values")
plt.ylabel("Density")
plt.legend()

# Max Normalized Data Density Distribution
plt.subplot(2, 2, 4)
density, bins = np.histogram(max_normalized, bins=30, density=True)
plt.plot((bins[:-1] + bins[1:]) / 2, density, color='red', label="Max Normalized Data")
plt.title("Max Normalized Distribution")
plt.xlabel("Feature Values")
plt.ylabel("Density")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # __Polynomial regression and Feature Engineering__
# * Linear Polynomial (Degree 1) $\mathbf{P(x) = a_1x + a_0}$
# * Quadratic Polynomial (Degree 2) $\mathbf{P(x) = a_2x^2 + a_1x + a_0}$
# * Cubic Polynomial (Degree 3) $\mathbf{P(x) = a_3x^3 + a_2x^2 + a_1x + a_0}$
# * General Polynomial (Degree n) $\mathbf{P(x) = a_nx^n + a_{n-1}x^{n-1} + \dots + a_1x + a_0}$
# - A polynomial is a mathematical expression combining variables raised to powers through basic operations.
# - __Polynomial regression__ captures curved relationships, extending the concept to fit data points effectively.
# - __Feature engineering__ transforms features, like squaring or cubing, to reveal hidden non-linear trends in data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Generate synthetic dataset with more complexity
np.random.seed(42)
X = np.random.uniform(-10, 10, 100).reshape(-1, 1)  # Independent variable
y = 0.1 * (X**3) - 0.5 * (X**2) + 2 * X + np.random.normal(0, 15, 100).reshape(-1, 1)  # Cubic relationship with noise

# Create a single figure for all plots
plt.figure(figsize=(16, 12))

# Plot 1: Original Dataset
plt.subplot(2, 2, 1)
plt.scatter(X, y, color='blue', label='Original Data')
plt.title("Original Dataset")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()

# Plot 2: Linear Fit
model_linear = LinearRegression()
model_linear.fit(X, y)
y_pred_linear = model_linear.predict(X)
plt.subplot(2, 2, 2)
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred_linear, color='red', label='Linear Fit')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()

# Plot 3: Quadratic Polynomial Fit (Degree 2)
model_quad = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
model_quad.fit(X, y)
X_sorted = np.sort(X, axis=0)
y_pred_quad = model_quad.predict(X_sorted)
plt.subplot(2, 2, 3)
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X_sorted, y_pred_quad, color='green', label='Quadratic Fit')
plt.title("Polynomial Regression (Degree 2)")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()

# Plot 4: Cubic Polynomial Fit (Degree 3)
model_cubic = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())
model_cubic.fit(X, y)
y_pred_cubic = model_cubic.predict(X_sorted)
plt.subplot(2, 2, 4)
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X_sorted, y_pred_cubic, color='orange', label='Cubic Fit')
plt.title("Polynomial Regression (Degree 3)")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()

# Show all plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # __Equations in Vector form__
# * Signle feature and single point straight line equation
#   * $\mathbf{f_{w,b}(x) = w \cdot x + b}$
# * Multi features and muti point straght line equation
#   * $\mathbf{f_{\vec{w}, b}(\vec{x}^{(i)}) = \left( \sum_{j=1}^{n} w_j x_j^{(i)} \right) + b}$
#     * ${i = 1, 2, 3, ..., m}$ to represent mulitple points
#     * ${j = 1, 2, 3, ..., n}$ to represent mulitple features
# * Vector form of the equation
#   * $\mathbf{f_{\vec{w}, b}(\vec{x}) = \vec{w} \cdot \vec{x} + b}$
# * Gradient descent for single feature
#   * $\mathbf{w = w - \alpha \cdot \frac{2}{m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right) \cdot x^{(i)}}$
#     * Where $\frac{\partial J(w,b)}{\partial w} = \frac{1}{m}\sum_{i=1}^{m}\left( f_{w,b}(x^{(i)}) - y^{(i)} \right)x^{(i)}$
#   * $\mathbf{b = b - \alpha \cdot \frac{2}{m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right)}$
#     * Where $\frac{\partial J(w,b)}{\partial b} = \frac{1}{m}\sum_{i=1}^{m}\left( f_{w,b}(x^{(i)}) - y^{(i)} \right)$
#   * Simultaneous update of ${w}$ and ${b}$
# * Gradient descent for n features where n > 1
#   * For ${j = 1}$ $\mathbf{w_1 = w_1 - \alpha \cdot \frac{2}{m} \sum_{i=1}^{m} \left( f_{\vec{w}, b}(\vec{x}^{(i)}) - y^{(i)} \right) \cdot x_1^{(i)}}$
#   * For ${j = n}$ $\mathbf{w_n = w_n - \alpha \cdot \frac{2}{m} \sum_{i=1}^{m} \Bigl( f_{\vec{w}, b}(\vec{x}^{(i)}) - y^{(i)} \Bigr) \cdot x_n^{(i)}}$
#   * $\mathbf{b = b - \alpha \cdot \frac{2}{m}\sum_{i=1}^{m} \Bigl( f_{\vec{w}, b}(\vec{x}^{(i)}) - y^{(i)} \Bigr)}$
#   * Simultaneous update of ${w_j = 1, 2, 3,..., n}$ and ${b}$

# %%
df_train_refined.to_csv('train_refined_numeric.csv', index=False)

# %%
os.listdir()
# Out:
# ['train.csv',
#  'feature_details_analysis.xlsx',
#  'data_description.txt',
#  'feature_classification.csv',
#  'train_refined - Copy.csv',
#  'feature_classification - Copy.csv',
#  'train_refined.csv',
#  'train_refined - Copy (2).csv',
#  'train_refined_numeric.csv']
