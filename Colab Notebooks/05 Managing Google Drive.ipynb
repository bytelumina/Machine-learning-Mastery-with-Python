# %% [markdown]
# # __Mounting google drive__
# #### Demonstrate how to connect Colab to Google Drive using the __google.colab__ module.
# #### Use __from google.colab import driv__e to import the drive submodule conveniently.
# #### Check the current directory with __os.getcwd()__ to verify the mounting point.
# #### Follow steps to authorize Google Drive access and complete the mounting process.
# #### Verify mounted drive and change directories to store and retrieve data safely.

# %%
from google.colab import drive
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
drive.mount('content')
# Out:
# Mounted at content

# %%
os.listdir()
# Out:
# ['.config', 'content', 'sample_data']

# %%
os.chdir('content')

# %%
os.listdir()
# Out:
# ['MyDrive',
#  '.shortcut-targets-by-id',
#  '.file-revisions-by-id',
#  '.Trash-0',
#  '.Encrypted']

# %%
os.chdir('MyDrive')

# %%
os.listdir()
# Out:
# ['keys',
#  '.ipynb_checkpoints',
#  '.virtual_documents',
#  'Business',
#  'Colab Notebooks',
#  'Untitled.ipynb']

# %%
os.chdir('Colab Notebooks')

# %%
os.listdir()
# Out:
# ['Copy of 03 Numpy in Python.ipynb',
#  '02 Crash Course on Python and Google Colab.ipynb',
#  'Copy of 04 Pandas in Python',
#  '04 Pandas in Python.ipynb',
#  '03 Numpy in Python.ipynb']

# %%
# Create a sample CSV file
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# Save the DataFrame to a CSV file
df.to_csv('sample.csv', index=False)
print('A new file sample.csv is created')
os.listdir()
# Out:
# A new file sample.csv is created
# ['Copy of 03 Numpy in Python.ipynb',
#  '02 Crash Course on Python and Google Colab.ipynb',
#  'Copy of 04 Pandas in Python',
#  '04 Pandas in Python.ipynb',
#  '03 Numpy in Python.ipynb',
#  'sample.csv']
